# %%
import pandas                   as pd
import numpy                    as np
import matplotlib.pyplot        as plt
from   statsmodels.tsa.seasonal import seasonal_decompose

### Ejemplo: generamos datos con estacionalidad
#np.random.seed(42)

number_of_days  = 1000
date_range      = pd.date_range(start='2025-01-01', periods=number_of_days, freq='D')

trend           = np.linspace(10, 50, number_of_days)  # linear trend

seasonality     = 10*np.sin(2*np.pi*date_range.month/12)

noise           = np.random.normal(0, 2, number_of_days)

### Componemos la serie temporal
data            = trend + seasonality + noise


### graficamos
plt.plot(data,color="black",lw=1)
plt.show()
# Out:
# '\ndecomposition.plot()\nplt.tight_layout()\nplt.show()\n'

# %%
### Creamos la serie de tiempo en un DataFrame
ts = pd.Series(data, index=date_range)

### Descomponemos la serie con "seasonal_decompose" 
decomposition = seasonal_decompose(ts, model='additive', period=365,extrapolate_trend=1)


print(ts)
print(decomposition.trend)
print(decomposition.seasonal)
print(decomposition.resid)
### Graficamos las componentes 

decomposition.plot()
plt.tight_layout()
plt.show()
# Out:
# 2025-01-01    17.050507
# 2025-01-02    16.391816
# 2025-01-03    16.814375
# 2025-01-04    15.683298
# 2025-01-05    14.941438
#                 ...
# 2027-09-23    38.542137
# 2027-09-24    40.958396
# 2027-09-25    39.390908
# 2027-09-26    38.810711
# 2027-09-27    40.028155
# Freq: D, Length: 1000, dtype: float64
# 2025-01-01    11.439945
# 2025-01-02    11.472712
# 2025-01-03    11.505479
# 2025-01-04    11.538246
# 2025-01-05    11.571012
#                 ...
# 2027-09-23    49.087437
# 2027-09-24    49.123079
# 2027-09-25    49.158722
# 2027-09-26    49.194364
# 2027-09-27    49.230007
# Freq: D, Name: trend, Length: 1000, dtype: float64
# 2025-01-01     5.538797
# 2025-01-02     5.173342
# 2025-01-03     6.412086
# 2025-01-04     3.735561
# 2025-01-05     4.438829
#                 ...
# 2027-09-23    -9.586829
# 2027-09-24   -10.268380
# 2027-09-25   -10.418229
# 2027-09-26    -9.529502
# 2027-09-27    -9.209907
# Freq: D, Name: seasonal, Length: 1000, dtype: float64
# 2025-01-01    0.071765
# 2025-01-02   -0.254237
# 2025-01-03   -1.103190
# 2025-01-04    0.409492
# 2025-01-05   -1.068403
#                 ...
# 2027-09-23   -0.958471
# 2027-09-24    2.103697
# 2027-09-25    0.650415
# 2027-09-26   -0.854152
# 2027-09-27    0.008056
# Freq: D, Name: resid, Length: 1000, dtype: float64

# %%
print(np.mean(decomposition.resid))
print(np.std(decomposition.resid))
# Out:
# -0.023414806263240485
# 1.5591312352152007

# %%
import pandas as pd

id = "17iCHWJF4gU0litHn0ZGnKS8hbTsOXE39" 
dowloand_url = f"https://drive.google.com/uc?export=download&id={id}"
TabData = pd.read_csv(dowloand_url, sep ='\t')
TabData.head()


Temp = TabData.iloc[:,4].replace('NULO', np.nan).astype(float)
plt.plot(Temp)

Ns= 1000
muestraT= Temp [0:Ns]
print(np.mean(muestraT))
print(np.std(muestraT))
plt.plot(muestraT, color='black')
plt.plot(np.ones(Ns)*np.mean(muestraT), color='red')
plt.plot(np.ones(Ns)*np.mean(muestraT)+np.std(muestraT), color='green')
plt.plot(np.ones(Ns)*np.mean(muestraT)-np.std(muestraT), color='blue')
# Out:
# 11.752805611222445
# 4.159833599489223

# %%
### Definimos fechas con formato datetime
Fech = TabData.iloc[:,0]
FechasTemp = pd.to_datetime(Fech[0:Ns])

ts = pd.Series(muestraT, index=FechasTemp)

decomposition = seasonal_decompose(ts, model='additive', period=365,extrapolate_trend=1)
decomposition.plot()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 7
#       3 FechasTemp = pd.to_datetime(Fech[0:Ns])
#       5 ts = pd.Series(muestraT, index=FechasTemp)
# ----> 7 decomposition = seasonal_decompose(ts, model='additive', period=365,extrapolate_trend=1)
#       8 decomposition.plot()
#       9 plt.tight_layout()
#
# File c:\Users\eagel\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\seasonal.py:154, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     151 nobs = len(x)
#     153 if not np.all(np.isfinite(x)):
# --> 154     raise ValueError("This function does not handle missing values")
#     155 if model.startswith("m"):
#     156     if np.any(x <= 0):
#
# ValueError: This function does not handle missing values

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Temp
#
# NameError: name 'Temp' is not defined
